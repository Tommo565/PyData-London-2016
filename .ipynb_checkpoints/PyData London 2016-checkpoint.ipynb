# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# # A Jupyter Notebook of all my favourite stuff from Pydata London 2016!

# %% [markdown]
# <img src = "img/pydata-london-2016.png">

# %% [markdown]
# So I was lucky enough to get DfT to pay for my ticket to Pydata 2016. It was AWESOME and I met some really cool people and saw some amazing stuff. On the downside, the food wasn't great but I soon figured out that nobody cared if you went upstairs and helped yourself to the Bloomberg stuff so it worked out OK!
#
# Anyways, I'e listed out what I thought the best talks were but feel free to check out the <a href = "https://www.youtube.com/playlist?list=PLGVZCDnMOq0qfJkoiFj-hN7lSHgQzXtqQ">full list of Pydata 2016 talks</a> as there is literally hours and hours worth of awesome talks and tutorials to view. You might also want to check out the <a href = "https://www.youtube.com/watch?v=5FwpxS1AfAY&list=PLGVZCDnMOq0q6hrjJA56bq18eHtGusYJK">Pydata London 2015 Talks</a> as well.
#
# So, in no particular order...

# %% [markdown]
# ## Travis Oliphant (Creator of Scipy & Numpy): Scaling Pydata up and out

# %%
YouTubeVideo("-aFTKM3nmZo",width=1200,height=800)

# %% [markdown]
# <a href = "www.slideshare.net/teoliphant/scaling-pydata-up-and-out">Slides</a>

# %% [markdown]
# ## Tariq Rashid - A Gentle Introduction to Neural Networks and making your own with Python

# %%
YouTubeVideo("2sevic5Vy4E",width=1200,height=800)

# %% [markdown]
# <a href = "https://docs.google.com/presentation/d/1Mai96er3d9Tca6mwVaO_bI7nZ09L6QQbww233yAnaGg/edit">Slides</a><br/>
# <a href = "https://github.com/makeyourownneuralnetwork/makeyourownneuralnetwork">Github</a><br/>

# %% [markdown]
# ## Andreas Freise: Laser ranging in a new dimension

# %%
YouTubeVideo("BXID4teFfDc",width=1200,height=800)

# %% [markdown]
# <a href = "http://www.gwoptics.org/talks/2016/pydata/">Slides</a>

# %% [markdown]
# ## Tetiana Ivanova - How to become a Data Scientist in 6 months

# %%
YouTubeVideo("rIofV14c0tc",width=1200,height=800)

# %% [markdown]
# ## Peadar Coyle - Lies damned lies and statistics in Python

# %%
YouTubeVideo("YUh46N-SZ34",width=1200,height=800)

# %% [markdown]
# <a href = "https://github.com/springcoil/PyDataLondonTutorial">Github</a>

# %% [markdown]
# ## Bryan Van de Ven - Bokeh for Data Applications and Visualization

# %%
YouTubeVideo("h0y90MyGo-c",width=1200,height=800)

# %% [markdown]
# ## Sylvain Corlay - Interactive Visualization in Jupyter with Bqplot and Interactive Widgets

# %%
YouTubeVideo("eVET9IYgbao",width=1200,height=800)

# %% [markdown]
# <a href = "https://github.com/SylvainCorlay/PyDataLondon2016">Github</a><br/>

# %% [markdown]
# ## Thomas Kluyver & Min Ragan Kelley - Customising nbconvert how to turn Jupyter notebooks into anything you want

# %%
YouTubeVideo("9d7ZQWUIPyw",width=1200,height=800)

# %% [markdown]
# <a href = "https://github.com/takluyver/customising-nbconvert">Github</a>

# %% [markdown]
# ## Annabelle Rolland - Classifying train and car journeys using telematics data

# %%
YouTubeVideo("zBaaP8uE7S0",width=1200,height=800)

# %% [markdown]
# <a href = "https://speakerdeck.com/annabeller/classifying-train-and-car-journeys-using-telematics-data">Slides</a>

# %% [markdown]
# ## Calvin Giles - Finding needles in haystacks with Deep Neural Networks

# %%
YouTubeVideo("bV1w_Q2Ihh4",width=1200,height=800)

# %% [markdown]
# ## Vincent D Warmerdam - The Duct Tape of Heroes Bayesian statistics

# %%
YouTubeVideo("dE5j6NW-Kzg",width=1200,height=800)
